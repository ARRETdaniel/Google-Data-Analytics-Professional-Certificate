# %% [markdown]
# # Python Code for KNN from Scratch
# https://medium.com/coding-blocks/k-nearest-neighbors-using-python-f4784299b8d4

# %%
from sklearn.preprocessing import MinMaxScaler
from numpy import asarray
import pandas as pd
import csv
import pprint
#import numpy as np
# https://www.edureka.co/community/42836/how-to-read-pandas-csv-file-with-no-header

df = pd.read_csv(
    'Course Challenge Dataset - Scenario 1 - Scenario 1_ Pharmacy Data - Part 1.csv',  skiprows=1, header=None, na_values='?')

df.dtypes
# Out:
# 0      int64
# 1      int64
# 2    float64
# 3     object
# 4     object
# dtype: object

# %% [markdown]
# ## remove dollar sign in pandas
# https://pbpython.com/currency-cleanup.html

# %%
def clean_currency(x):
    """ If the value is a string, then remove currency symbol and delimiters
    otherwise, the value is numeric and can be converted
    """
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)

# %%
df[3] = df[3].apply(clean_currency).astype('float')
df[4] = df[4].apply(clean_currency).astype('float')
df[3].apply(lambda x: type(x).__name__)


df
# Out:
#      0    1     2      3       4
# 0    1  120   6.0  25.02  2686.0
# 1    2  144  18.0  75.06  4291.0
# 2    3  394  13.0  54.21  5168.0
# 3    4  122  17.0  70.89  2844.0
# 4    5  132   3.0  12.51  3241.0
# 5    6  140  10.0  41.70  3865.0
# 6    7  139   4.0  16.68  3772.0
# 7    8  256  16.0  66.72  4540.0
# 8    9  306  20.0  83.40  4757.0
# 9   10  129   7.0  29.19  3130.0
# 10  11  118  18.0  75.06  2632.0
# 11  12  372  16.0  66.72  4950.0
# 12  13  396  11.0  45.87  5220.0
# 13  14  357   1.0   4.17  4808.0
# 14  15  138   NaN    NaN  3619.0
# 15  16  383  18.0  75.06  5133.0
# 16  17  132   8.0  33.36  3259.0
# 17  18  390  16.0  66.72  5152.0
# 18  19  149   5.0  20.85  4377.0
# 19  20  360  19.0  79.23  4844.0
# 20  21  141  16.0  66.72  3906.0
# 21  22  296  19.0  79.23  4594.0
# 22  23  367   3.0  12.51  4883.0
# 23  24  112   9.0  37.53  2376.0
# 24  25  133  17.0  70.89  3313.0
# 25  26  124  13.0  54.21  3003.0
# 26  27  396  19.0  79.23  5256.0
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split

dataset = df

# %%
dataset.head()
# Out:
#    0    1     2      3       4
# 0  1  120   6.0  25.02  2686.0
# 1  2  144  18.0  75.06  4291.0
# 2  3  394  13.0  54.21  5168.0
# 3  4  122  17.0  70.89  2844.0
# 4  5  132   3.0  12.51  3241.0

# %%
dataset.shape
# Out:
# (38, 5)

# %%
for i in range(dataset.shape[1]):
	# count number of rows with missing values
	n_miss = dataset[[i]].isnull().sum()
	perc = n_miss / dataset.shape[0] * 100
	print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 1 (2.6%)
# > 3, Missing: 1 (2.6%)
# > 4, Missing: 0 (0.0%)

# %%
# summarize the horse colic dataset
from pandas import read_csv
# load dataset

# summarize the first few rows
print(dataset.head())
# summarize the number of rows with missing values for each column
for i in range(dataset.shape[1]):
	# count number of rows with missing values
	n_miss = dataset[[i]].isnull().sum()
	perc = n_miss / dataset.shape[0] * 100
	print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
#    0    1     2      3       4
# 0  1  120   6.0  25.02  2686.0
# 1  2  144  18.0  75.06  4291.0
# 2  3  394  13.0  54.21  5168.0
# 3  4  122  17.0  70.89  2844.0
# 4  5  132   3.0  12.51  3241.0
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 1 (2.6%)
# > 3, Missing: 1 (2.6%)
# > 4, Missing: 0 (0.0%)

# %% [markdown]
# https://machinelearningmastery.com/knn-imputation-for-missing-values-in-machine-learning/

# %%
# define imputer

# knn imputation transform for the horse colic dataset
from numpy import isnan
from pandas import read_csv
from pandas import isna
from sklearn.impute import KNNImputer
from sklearn.metrics.pairwise import nan_euclidean_distances

#imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
imputer = KNNImputer(n_neighbors=1)

# %% [markdown]
# https://machinelearningmastery.com/handle-missing-data-python/

# %%
print(dataset)
print(dataset.describe())
# Out:
#      0    1     2      3       4
# 0    1  120   6.0  25.02  2686.0
# 1    2  144  18.0  75.06  4291.0
# 2    3  394  13.0  54.21  5168.0
# 3    4  122  17.0  70.89  2844.0
# 4    5  132   3.0  12.51  3241.0
# 5    6  140  10.0  41.70  3865.0
# 6    7  139   4.0  16.68  3772.0
# 7    8  256  16.0  66.72  4540.0
# 8    9  306  20.0  83.40  4757.0
# 9   10  129   7.0  29.19  3130.0
# 10  11  118  18.0  75.06  2632.0
# 11  12  372  16.0  66.72  4950.0
# 12  13  396  11.0  45.87  5220.0
# 13  14  357   1.0   4.17  4808.0
# 14  15  138   NaN    NaN  3619.0
# 15  16  383  18.0  75.06  5133.0
# 16  17  132   8.0  33.36  3259.0
# 17  18  390  16.0  66.72  5152.0
# 18  19  149   5.0  20.85  4377.0
# 19  20  360  19.0  79.23  4844.0
# 20  21  141  16.0  66.72  3906.0
# 21  22  296  19.0  79.23  4594.0
# 22  23  367   3.0  12.51  4883.0
# 23  24  112   9.0  37.53  2376.0
# 24  25  133  17.0  70.89  3313.0
# 25  26  124  13.0  54.21  3003.0
# 26  27  396  19.0  79.23  5256.0
# ...

# %% [markdown]
# https://medium.com/@kyawsawhtoon/a-guide-to-knn-imputation-95e2dc496e

# %%
from sklearn.impute import KNNImputer
from matplotlib import pyplot

imputer = KNNImputer(n_neighbors=5)
df = pd.DataFrame(imputer.fit_transform(dataset), columns=df.columns)

# plot model performance for comparison
#pyplot.boxplot(df, labels=None, showmeans=True)
#pyplot.show()

df


# https://www.kite.com/python/answers/how-to-add-a-header-to-a-csv-file-in-python#:~:text=Use%20pandas.,header%20to%20a%20CSV%20file&text=read_csv(file%2C%20header%3DNone,header%20to%20the%20CSV%20file.
df.to_csv(r'csvexample3.csv', header=['Store Number', 'Average Daily Customers', 'Average Daily Splashtastic Sales(Units)',
                                      'Average Daily Splashtastic Sales(Dollars)', 'Average Total Daily Sales(All Products)'])


print(df)
# Out:
#        0      1     2       3       4
# 0    1.0  120.0   6.0  25.020  2686.0
# 1    2.0  144.0  18.0  75.060  4291.0
# 2    3.0  394.0  13.0  54.210  5168.0
# 3    4.0  122.0  17.0  70.890  2844.0
# 4    5.0  132.0   3.0  12.510  3241.0
# 5    6.0  140.0  10.0  41.700  3865.0
# 6    7.0  139.0   4.0  16.680  3772.0
# 7    8.0  256.0  16.0  66.720  4540.0
# 8    9.0  306.0  20.0  83.400  4757.0
# 9   10.0  129.0   7.0  29.190  3130.0
# 10  11.0  118.0  18.0  75.060  2632.0
# 11  12.0  372.0  16.0  66.720  4950.0
# 12  13.0  396.0  11.0  45.870  5220.0
# 13  14.0  357.0   1.0   4.170  4808.0
# 14  15.0  138.0   9.4  39.198  3619.0
# 15  16.0  383.0  18.0  75.060  5133.0
# 16  17.0  132.0   8.0  33.360  3259.0
# 17  18.0  390.0  16.0  66.720  5152.0
# 18  19.0  149.0   5.0  20.850  4377.0
# 19  20.0  360.0  19.0  79.230  4844.0
# 20  21.0  141.0  16.0  66.720  3906.0
# 21  22.0  296.0  19.0  79.230  4594.0
# 22  23.0  367.0   3.0  12.510  4883.0
# 23  24.0  112.0   9.0  37.530  2376.0
# ...

# %%
myFile = open('csvexample3.csv', 'w')
with myFile:
   writer = csv.writer(myFile)
   writer.writerows(df)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-260-301bc62916c9> in <module>
#       2 with myFile:
#       3    writer = csv.writer(myFile)
# ----> 4    writer.writerows(df)
#
# Error: iterable expected, not int

# %% [markdown]
# ---------------------------------

# %%
# split into input and output elements
data = dataset.values
ix = [i for i in range(data.shape[1]) if i != 4]
X, y = data[:, ix], data[:, 4]
# print total missing
print('Missing: %d' % sum(isna(X).flatten()))
# define imputer
imputer = KNNImputer()
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)

data
# Out:
# Missing: 2
# array([[1.000e+00, 1.200e+02, 6.000e+00, 2.502e+01, 2.686e+03],
#        [2.000e+00, 1.440e+02, 1.800e+01, 7.506e+01, 4.291e+03],
#        [3.000e+00, 3.940e+02, 1.300e+01, 5.421e+01, 5.168e+03],
#        [4.000e+00, 1.220e+02, 1.700e+01, 7.089e+01, 2.844e+03],
#        [5.000e+00, 1.320e+02, 3.000e+00, 1.251e+01, 3.241e+03],
#        [6.000e+00, 1.400e+02, 1.000e+01, 4.170e+01, 3.865e+03],
#        [7.000e+00, 1.390e+02, 4.000e+00, 1.668e+01, 3.772e+03],
#        [8.000e+00, 2.560e+02, 1.600e+01, 6.672e+01, 4.540e+03],
#        [9.000e+00, 3.060e+02, 2.000e+01, 8.340e+01, 4.757e+03],
#        [1.000e+01, 1.290e+02, 7.000e+00, 2.919e+01, 3.130e+03],
#        [1.100e+01, 1.180e+02, 1.800e+01, 7.506e+01, 2.632e+03],
#        [1.200e+01, 3.720e+02, 1.600e+01, 6.672e+01, 4.950e+03],
#        [1.300e+01, 3.960e+02, 1.100e+01, 4.587e+01, 5.220e+03],
#        [1.400e+01, 3.570e+02, 1.000e+00, 4.170e+00, 4.808e+03],
# ...

# %%
# split into input and output elements
data = dataset.values
ix = [i for i in range(data.shape[1]) if i != 4]
X, y = data[:, ix], data[:, 4]
# print total missing
print('Missing: %d' % sum(isna(X).flatten()))
# define imputer
imputer = KNNImputer()
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
# print total missing
print('Missing: %d' % sum(isnan(Xtrans).flatten()))
# Out:
# Missing: 2
# Missing: 0
